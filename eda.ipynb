# %%
import pandas as pd
import numpy as np
import random
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('data/russia_201901_1_tweets_csv_hashed.csv')
# Out:
# /anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:3020: DtypeWarning: Columns (29) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
data.columns
# Out:
# Index(['tweetid', 'userid', 'user_display_name', 'user_screen_name',
#        'user_reported_location', 'user_profile_description',
#        'user_profile_url', 'follower_count', 'following_count',
#        'account_creation_date', 'account_language', 'tweet_text', 'tweet_time',
#        'tweet_client_name', 'in_reply_to_tweetid', 'in_reply_to_userid',
#        'quoted_tweet_tweetid', 'is_retweet', 'retweet_userid',
#        'retweet_tweetid', 'latitude', 'longitude', 'quote_count',
#        'reply_count', 'like_count', 'retweet_count', 'hashtags', 'urls',
#        'user_mentions', 'poll_choices'],
#       dtype='object')

# %%
# I am making 2 toy subset Data Frames and 2 subsets Pandas Series 

### Retweets
retweets_mask = data['is_retweet'] == True
retweets = data[retweets_mask]


# Tweets
tweets_mask = data['is_retweet'] == False
tweets = data[tweets_mask]



#English Only
tweets_english = tweets[ tweets['account_language'] == 'en']
retweets_english = retweets[ retweets['account_language'] == 'en']

# %%
#Account Language for tweets and retweets

plt.figure(figsize=(5,3))
ax = sns.countplot(x='account_language', data=tweets)
# ax = sns.countplot(x='account_language', data=retweets)
sns.set(style="darkgrid")


plt.ylabel('Retweets Total', fontsize = 14)
plt.xlabel('Account Language', fontsize = 14)
plt.title('Retweets: Account Language Counts', fontsize = 14)
plt.grid(c = 'lightcyan')

plt.show()
plt.savefig('plots/retweet_language_counts.png')

# %%
plt.figure(figsize=(5,3))

sns.set(style="darkgrid")
ax = sns.countplot(x='account_language', data=tweets )


plt.ylabel('Tweets Total', fontsize = 14)
plt.xlabel('Account Language', fontsize = 14)
plt.title('Retweets: Account Language Counts', fontsize = 14)
plt.grid(c = 'lightcyan')

plt.show()
plt.savefig('plots/tweet_language_counts.png')

# %%
tweets[tweets['account_language'] == 'ru']['tweet_text'].sample(8)
# Out:
# 730642    Купил темно, почти черные шторы в ванну, думал...
# 426927    http://t.co/KaUUfUFYVX #г химки вашутинское шо...
# 614300    Мне,умоляю,чуда!чтобы неизмеримо откуда и до к...
# 161402    http://t.co/MkTuFLHFJ8 Монитор драйвера для as...
# 498808    Не скучаешь по друзьям из родного города? — оч...
# 754210    Пока еще сыроват https://t.co/2ZcKs0uIf6 но уж...
# 629850    http://t.co/OqwGm4NABv Драйвера genius usb lan...
# 667760    Song of the day: Confidence - What Comes Next\...
# Name: tweet_text, dtype: object

# %%
len(tweets[tweets['account_language'] == 'ru']['tweet_text'])
# Out:
# 1237

# %%
len(tweets[tweets['account_language'] == 'fr']['tweet_text'])
# Out:
# 8125

# %%
len(tweets[tweets['account_language'] == 'id']['tweet_text'])
# Out:
# 185

# %%
len(tweets[tweets['account_language'] == 'tr']['tweet_text'])
# Out:
# 53

# %%
len(tweets[tweets['account_language'] == 'ro']['tweet_text'])
# Out:
# 17

# %%
len(tweets[tweets['account_language'] == 'en']['tweet_text'])
# Out:
# 162342

# %%
tweets[tweets['account_language'] == 'id']['tweet_text'][:20]
# Out:
# 409       ngajakin meet up tapi pas udah ketemuu.. diem,...
# 1719      @katyperry may ke indo nih💃💃terus kamu kapan t...
# 3542                                 http://t.co/CVv4g9r8Wx
# 3608                                               00:00 💣🎆
# 23051     videocall😅/anak kecil yang imuuudhhh😆😆 http://...
# 24974       @nazlaazhr @ArianasIndo Pretty girl bangeettt😍😨
# 25505     good luck buat temen temen grup line gue yang ...
# 26369     "@sirdavidD: Well I vote for @katyperry to win...
# 26625     "@Hi_Im_Hazzy: @E4OloCLnhgkcTD+KEjDYP3aHJ1VqXM...
# 72922     @Ikaylnt Bangheett ka ..kita kan masih kecil a...
# 73779                                http://t.co/21t4e84oA0
# 74045     HEYY KATYCATS LOOK IT👉"@IsmayaLive: INDONESIA,...
# 116241    "@dailyteenwords: I just want my long holiday ...
# 117120                              PAGEEE EPRI BADEEEHH 😝💤
# 117425    "@Hi_Im_Hazzy: @E4OloCLnhgkcTD+KEjDYP3aHJ1VqXM...
# 117922    berharap nanti march ketemu orang baik ngajak ...
# 119066                  "@islamicfreedom: Only Allah Knows"
# 164390    "@iKatyCats: It's been 1 year since PRISM has ...
# 164810    "@KatySlaysUrFav: OMFG LADY GAGA REPLIED TO MY...
# 165797                                              night x
# Name: tweet_text, dtype: object

# %%
tweets.columns
# Out:
# Index(['tweetid', 'userid', 'user_display_name', 'user_screen_name',
#        'user_reported_location', 'user_profile_description',
#        'user_profile_url', 'follower_count', 'following_count',
#        'account_creation_date', 'account_language', 'tweet_text', 'tweet_time',
#        'tweet_client_name', 'in_reply_to_tweetid', 'in_reply_to_userid',
#        'quoted_tweet_tweetid', 'is_retweet', 'retweet_userid',
#        'retweet_tweetid', 'latitude', 'longitude', 'quote_count',
#        'reply_count', 'like_count', 'retweet_count', 'hashtags', 'urls',
#        'user_mentions', 'poll_choices'],
#       dtype='object')

# %%
len(tweets['userid'][tweets['account_language'] == 'en'].unique())
# Out:
# 333

# %%
tweets[tweets['account_language'] == 'en'].tweet_text.sample(5)
# Out:
# 426347    #CrookedHillary #HillaryClintonLiesMatter #Hil...
# 389761                                  @Yahgirlabby No.\n😡
# 455678    Boston Marathon Bomber Tsarnaev Severely Injur...
# 380853    Stormy Daniels' Lawyer Gets The Wrong Michael ...
# 158223    #obamaisanidiot #obamaistheworstpresidentever ...
# Name: tweet_text, dtype: object

# %%
sample = tweets_english.tweet_text.sample(10)

# %%
sample
# Out:
# 665935    If today was perfect there would be no need fo...
# 303760    u retires from US GOPsen on first day full of ...
# 345236    Fox News Chief Calls Donald Trump Attack on Me...
# 3415           @PradRachael @FLOTUS https://t.co/j6zF8UiIJJ
# 694479    SEE IT: NY1 anchor Pat Kiernan goes shirtless ...
# 502865        @AffableCreation SİZİN SEZIER daha BİLGİSAYAR
# 253576    Donald Trump makes an appearance on local airw...
# 256909             @Speedcomesfirst https://t.co/IORyiFrotA
# 685660    @JudicialWatch #BoycottCNN\n\n#FakeNews\n\n#CN...
# 375742    #Allah #banislam #banmoques #islamisevil #Isla...
# Name: tweet_text, dtype: object

# %%
import preprocessor as p
import re

import nltk
from nltk.stem.wordnet import WordNetLemmatizer
from nltk.stem.snowball import SnowballStemmer

import string


def clean_tweet_text(text_column):
    '''
    INPUT: 
    Pandas dataframe column w/tweets text: 
    OUTPUT: 
    Cleaned Docs, bag of words (bow)
    symbol_set charachters removed,
    specified stop words removed
    punctuation removed
    words stemmed and lemmatized
    non-english words removed
    words <3 chars removed
    
    
    '''
    
    
    punct = set(string.punctuation)

    punct.remove('@')
    punct.remove('#')
    punct.add('🇺🇸')
    punct.add('🇯🇵')
    punct.add('🇰🇷')
    punct.add('🇩🇪')
    punct.add('🇨🇳')
    punct.add('🇫🇷')
    punct.add('🇪🇸')
    punct.add('🇮🇹')
    punct.add('🇷🇺')
    punct.add('🇬🇧')
    punct.add('🤗')



    ### English stop words from NLTK   
    stop_words = set(nltk.corpus.stopwords.words('english')) 


    ### Custom stop words. 
    added_stop_words = {'rt', 'via', 'new', 'time', 'today', 'one', 'say', 'get', 'go', 'im', 'know', 'need', 'made', 'https', 'http', 'that', 'would', 'take', 'your', 'two', 'yes', 'back', 'look', 'see', 'amp', 'tell', 'give', 'httpst', 'htt', 'use', 'dont', 'thing', 'man', 'thank', 'lol', 'cc', 'didnt', 'hey', 'like', 'ask', 'let', 'even', 'also', 'ok', 'etc', 'thank', 'ive', 'hi', 'wasnt'}

    ### stemmer and lemmer

    lemmer = WordNetLemmatizer()
    stemmer = SnowballStemmer('english')
    
    # converting from pd to list
    corpus = text_column.values.tolist()
    
    #Removing all HTTPs
    docs_no_http = [ re.sub(r'https?:\/\/.*\/\w*', '', doc) for doc in corpus ]
    #First ---> tokenize docs
    tokenized_docs = [doc.split() for doc in docs_no_http]
    # Lower case words in doc
    tokenized_docs_lowered  = [[word.lower() for word in doc]
                                for doc in tokenized_docs]

    # Removing punctuation from docs
    docs_no_punct = [[remove_symbols(word, punct) for word in doc] 
                    for doc in tokenized_docs_lowered]

    # Removing added stop words    
    docs_no_stops1 = [[word for word in doc if word not in added_stop_words] 
                     for doc in docs_no_punct]
    # Removing nltkstop words
    docs_no_stops = [[word for word in doc if word not in stop_words ] 
                     for doc in docs_no_stops1]
    # Lemmatizing words in docs
    docs_lemmatized = [[lemmer.lemmatize(word) for word in doc]
                      for doc in docs_no_stops]
    
    # Stemming words in docs
    docs_stemmed = [[stemmer.stem(word) for word in doc]
                      for doc in docs_lemmatized]
    
    # Removes mentions, emotions, hashtags and emojies
    docs_no_mentions = [preprocessing_text(' '.join(doc)) for doc in docs_stemmed]
    
    # Removes all non-english charachters and any other different charachters
    docs_english_only = [re.sub(r'[^a-zA-Z]', " ", doc) for doc in docs_no_mentions]
    
    # keeping words that are more than 2 chars long
    cleaned_docs = []
    for doc in docs_english_only:
        cleaned_docs.append(' '.join(word for word in doc.split() if len(word)>2))
        
    
    # converting cleaned docs into list of lists i.e bag of words (bow) per each doc
    bow = [list(tweet.split(' ')) for tweet in cleaned_docs]
    
   
    return cleaned_docs, bow 



def preprocessing_text(text):
    '''
    INPUT: str
    OUTPUT: str w/ emojies, urls, hashtags and mentions removed
    '''
    p.set_options(p.OPT.EMOJI, p.OPT.URL, p.OPT.HASHTAG, p.OPT.MENTION, p.OPT.NUMBER,
    p.OPT.RESERVED, p.OPT.SMILEY)
    clean_text = p.clean(text)

    return clean_text

def remove_symbols(word, symbol_set):

    '''
    INPUT: STR,   symbol set (i.e. punctuation)
    OUTPUT:word w/ removed symbols from specified symbol set
    '''
    return ''.join(char for char in word 
                    if char not in symbol_set)

# %%
clean = clean_tweet_text(sample)

# %%
clean
# Out:
# (['civil societi outcri hijack hooligan',
#   'messag clear western hemispher nation truli becom hemispher freedom that stand peopl cuba venezuela stand oppressor read ope'],
#  [['civil', 'societi', 'outcri', 'hijack', 'hooligan'],
#   ['messag',
#    'clear',
#    'western',
#    'hemispher',
#    'nation',
#    'truli',
#    'becom',
#    'hemispher',
#    'freedom',
#    'that',
#    'stand',
#    'peopl',
#    'cuba',
#    'venezuela',
#    'stand',
#    'oppressor',
#    'read',
#    'ope']])

# %%
sample
# Out:
# 526893                                      Rest In Hell! 💀
# 421160    #ByeFelicia #DropOutHillary #UnfitToLead  #DNC...
# Name: tweet_text, dtype: object
